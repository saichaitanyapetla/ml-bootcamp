# %% [markdown]
# ## scrapping

# %%
## scrapping --> data extraction from website

# %%
## why do we need data scrapping?
## helps in data analysis

# %%
## python gives us different modules to implement scrapping
## 1 --> beautiful soup
## 2 --> selenium
## 3 --> mechanical soup
## 4 --> lxml
## 5 --> requests

# %%
## here we use beautiful soup and requests

# %%
## eg

# %%
## want to extract info from google page
## 1 --> search tab
## 2 --> customer name
## 3 --> main elements
## of iphone 11

# %%
import requests
from bs4 import BeautifulSoup  ## useful for beautification of html
from urllib.request import urlopen ## requesting the url

# %% [raw]
# url='https://www.google.com/'

# %%
google_page=urlopen('https://www.google.com/')

# %%
google_page

# %%
google_page.read()
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="DP86aPbMDZ-4s75g9LkefA">(function(){var _g={kEI:\'oupmZdaEJM2l5NoPvcOiqAE\',kEXPI:\'0,793110,572358,206,4804,2316,383,1129371,1921,1195836,380734,16114,28684,22430,1362,12315,17584,4998,17075,35733,2711,2872,2891,4140,4208,4012,29880,788,27619,2403,6397,9938,1014,1,16916,2652,4,28691,4203,31160,22562,6675,7596,1,42154,2,16737,23024,5679,1021,31122,4568,6255,23421,1252,33064,2,2,1,26632,8155,23350,873,6578,1252,11804,7,1922,52238,20199,20136,14,82,13333,6873,472,26865,5403,3030,15816,1804,7734,15103,12432,5486,7959,8843,25773,5769,3626,12351,5208140,1999,2,297,283,132,49,32,499,5993673,2803214,3311,141,795,30314,2,2,2,2,2,44,9,1,5,5,3,23940177,4044106,16673,40902,2984,3,1599,3,503,3,1393942,727334,230
# ...

# %%
url
# Out:
# 'https://www.google.com/'

# %%
a=BeautifulSoup(google_page,'html.parser')

# %%
a.prettify()
# Out:
# ''

# %%
url=requests.get('https://www.google.com/') ## another way to get url

# %%
url.text ## another way to read the webpage
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="09fpVGo_SfHoDaJsbhw1yQ">(function(){var _g={kEI:\'yOdmZYz3PP2M5OUPxeuK8A0\',kEXPI:\'0,1365467,207,4804,2316,383,1129371,1920,1195800,681,380090,16114,28684,22431,1361,12315,4749,12835,4998,17075,38444,885,1987,2891,11754,606,29842,30848,2614,13491,230,1014,1,16916,2652,4,32894,26723,4437,22610,6627,7596,1,42154,2,16737,23024,6699,31123,4568,6252,23424,1252,33064,2,2,1,26632,5665,2490,23351,873,19633,7,1922,9779,42459,20198,20137,14,82,13332,6874,4069,23268,5403,3030,15816,1804,7734,8334,4944,1825,12431,961,12488,2170,6670,25773,5769,15977,5208141,999,999,2,580,134,47,529,5992466,1209,2803214,3311,936,4,30310,2,2,2,2,2,44,9,1,5,5,3,23940176,4060780,43886,3,1599,3,503,3,1393942,727334,23031936,8163,1033
# ...

# %%
a=BeautifulSoup(url.text,'html.parser') ## converts to  more readable format

# %%
b=a.find_all()

# %%
len(b)
# Out:
# 93

# %%
b[9].div.text
# Out:
# 'Search Images Maps Play YouTube News Gmail Drive More »Web History | Settings | Sign in'

# %%
c=a.find_all('div',{'class':'L3eUgb'})

# %%
d=a.find('L3eUgb')

# %%
b
# Out:
# [<html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>Google</title><script nonce="P6E6YRAx1X0O6mePnue8eg">(function(){var _g={kEI:'9-tmZZ-bJsOg5NoPz5mngA0',kEXPI:'0,1365467,207,4804,2316,383,1129371,1921,1195843,637,380090,16114,28684,22431,1361,12316,2819,14765,4997,17075,39331,1985,2891,8348,3406,606,29842,47183,1014,1,16916,2652,4,32894,26723,4437,22601,6636,7596,1,42154,2,16737,23024,5679,1020,31123,4568,6258,23418,1252,33064,2,2,1,6960,19672,8155,23350,873,19634,7,1922,9779,42459,20198,20137,14,82,13333,6873,473,26864,4415,988,2266,764,15816,1804,7734,15103,3571,686,8175,13240,87,121,2170,6670,25773,5769,1883,8791,5303,5203210,4931,1998,2,579,133,49,5993525,679,2803214,3452,795,2,30199,113,2,2,2,2,2,44,9,1,5,5,3,23940177,4044106,14298,2374,43887,3,1603,3,499,3,1732455,388821,23031936,7954,
# ...

# %%
a.prettify()
# Out:
# '<!DOCTYPE html>\n<html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN">\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>\n  <title>\n   Google\n  </title>\n  <script nonce="P6E6YRAx1X0O6mePnue8eg">\n   (function(){var _g={kEI:\'9-tmZZ-bJsOg5NoPz5mngA0\',kEXPI:\'0,1365467,207,4804,2316,383,1129371,1921,1195843,637,380090,16114,28684,22431,1361,12316,2819,14765,4997,17075,39331,1985,2891,8348,3406,606,29842,47183,1014,1,16916,2652,4,32894,26723,4437,22601,6636,7596,1,42154,2,16737,23024,5679,1020,31123,4568,6258,23418,1252,33064,2,2,1,6960,19672,8155,23350,873,19634,7,1922,9779,42459,20198,20137,14,82,13333,6873,473,26864,4415,988,2266,764,15816,1804,7734,15103,3571,686,8175,13240,87,121,2170,6670,25773,5769,1883,8791,5303,5203210,4931,1998,2,579,133,49,5993525,679,2803214,3452,795,2,30199,113,2,2,2,2,2,44,9,1,5,5,3,23940177,4044106,14298,23
# ...

# %%
b=a.find_all('a',{'class':'gb1'})

# %%
b
# Out:
# [<a class="gb1" href="https://www.google.com/imghp?hl=en&amp;tab=wi">Images</a>,
#  <a class="gb1" href="https://maps.google.co.in/maps?hl=en&amp;tab=wl">Maps</a>,
#  <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=w8">Play</a>,
#  <a class="gb1" href="https://www.youtube.com/?tab=w1">YouTube</a>,
#  <a class="gb1" href="https://news.google.com/?tab=wn">News</a>,
#  <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a>,
#  <a class="gb1" href="https://drive.google.com/?tab=wo">Drive</a>,
#  <a class="gb1" href="https://www.google.co.in/intl/en/about/products?tab=wh" style="text-decoration:none"><u>More</u> »</a>]

# %%
b[0].text
# Out:
# 'Images'
